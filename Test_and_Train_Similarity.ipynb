# %% [markdown]
# ## Test (Similarity Split , Random Split) and Train (Similarity Split, Random Split)

# %% [markdown]
# ## Size_nm

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data provided
data = {
    'Model': ['SVR', 'NND', 'DL', 'DT', 'RF', 'GBM'],
    'R2_Train_Random': [0.99, 0.99, 0.77, 0.94, 0.93, 0.97],
    'R2_Train_Similarity': [0.98, 0.97, 0.75, 0.92, 0.91, 0.95],
    'R2_Test_Random': [0.80, 0.62, 0.10, 0.94, 0.51, 0.48],
    'R2_Test_Similarity': [0.78, 0.60, 0.08, 0.90, 0.25, 0.45],
    'RMSE_Train_Random': [0.009, 0.012, 0.49, 0.23, 0.26, 0.14],
    'RMSE_Train_Similarity': [0.010, 0.013, 0.50, 0.24, 0.27, 0.15],
    'RMSE_Test_Random': [0.34, 0.47, 0.74, 0.23, 0.66, 0.56],
    'RMSE_Test_Similarity': [0.35, 0.49, 0.76, 0.24, 0.67, 0.57],
    'MAE_Train_Random': [0.009, 0.008, 0.38, 0.17, 0.20, 0.13],
    'MAE_Train_Similarity': [0.010, 0.009, 0.39, 0.18, 0.21, 0.14],
    'MAE_Test_Random': [0.16, 0.30, 0.56, 0.16, 0.54, 0.38],
    'MAE_Test_Similarity': [0.17, 0.31, 0.57, 0.17, 0.55, 0.39]
}

# Create DataFrame
df_sizeNM = pd.DataFrame(data)

# Plotting
fig, axs = plt.subplots(3, 2, figsize=(13, 10))

# Define bar width
bar_width = 0.2

# Plot R^2
indices = range(len(df_sizeNM['Model']))
axs[0, 0].bar([i - 0.25*bar_width for i in indices], df_sizeNM['R2_Train_Random'], width=bar_width, color='gray', edgecolor='black', hatch='//', label='R2 - Train Random')
axs[0, 0].bar([i + 0.25*bar_width for i in indices], df_sizeNM['R2_Train_Similarity'], width=bar_width, color='gray', edgecolor='black', hatch='.', label='R2 - Train Similarity')
axs[0, 0].set_ylabel('R²', fontsize=11, fontweight='bold')
axs[0, 0].set_xlabel('R²', fontsize=11, fontweight='bold')
axs[0, 0].set_xticks(indices)
axs[0, 0].set_xticklabels(df_sizeNM['Model'])
axs[0, 0].legend()

axs[0, 1].bar([i - 0.25*bar_width for i in indices], df_sizeNM['R2_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='//', label='R2 - Test Random')
axs[0, 1].bar([i + 0.25*bar_width for i in indices], df_sizeNM['R2_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='R2 - Test Similarity')
axs[0, 1].set_ylabel('R²', fontsize=11, fontweight='bold')
axs[0, 1].set_xticks(indices)
axs[0, 1].set_xticklabels(df_sizeNM['Model'])
axs[0, 1].legend()

# Plot RMSE
axs[1, 0].bar([i - 0.25*bar_width for i in indices], df_sizeNM['RMSE_Train_Random'], width=bar_width, color='gray', edgecolor='black', hatch='*', label='RMSE - Train Random')
axs[1, 0].bar([i + 0.25*bar_width for i in indices], df_sizeNM['RMSE_Train_Similarity'], width=bar_width, color='gray', edgecolor='black',hatch='.', label='RMSE - Train Similarity')
axs[1, 0].set_ylabel('RMSE', fontsize=11, fontweight='bold')
axs[1, 0].set_xticks(indices)
axs[1, 0].set_xticklabels(df_sizeNM['Model'])
axs[1, 0].set_yscale('log')
axs[1, 0].legend()

axs[1, 1].bar([i - 0.25*bar_width for i in indices], df_sizeNM['RMSE_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='*', label='RMSE - Test Random')
axs[1, 1].bar([i + 0.25*bar_width for i in indices], df_sizeNM['RMSE_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='RMSE - Test Similarity')
axs[1, 1].set_ylabel('RMSE', fontsize=11, fontweight='bold')
axs[1, 1].set_xticks(indices)
axs[1, 1].set_xticklabels(df_sizeNM['Model'])
axs[1, 1].set_yscale('log')
axs[1, 1].legend()

# Plot MAE
axs[2, 0].bar([i - 0.25*bar_width for i in indices], df_sizeNM['MAE_Train_Random'], width=bar_width, color='gray',edgecolor='black', hatch='/', label='MAE - Train Random')
axs[2, 0].bar([i + 0.25*bar_width for i in indices], df_sizeNM['MAE_Train_Similarity'], width=bar_width, color='gray',edgecolor='black', hatch='.', label='MAE - Train Similarity')
axs[2, 0].set_ylabel('MAE', fontsize=11, fontweight='bold')
axs[2, 0].set_xticks(indices)
axs[2, 0].set_xticklabels(df_sizeNM['Model'])
axs[2, 0].set_yscale('log')
axs[2, 0].legend()

axs[2, 1].bar([i - 0.25*bar_width for i in indices], df_sizeNM['MAE_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='/', label='MAE - Test Random')
axs[2, 1].bar([i + 0.25*bar_width for i in indices], df_sizeNM['MAE_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='MAE - Test Similarity')
axs[2, 1].set_ylabel('MAE', fontsize=11, fontweight='bold')
axs[2, 1].set_xticks(indices)
axs[2, 1].set_xticklabels(df_sizeNM['Model'])
axs[2, 1].set_yscale('log')
axs[2, 1].legend()

# General layout
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## S abs nm Y1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data provided
data = {
    'Model': ['SVR', 'NND', 'DL', 'DT', 'RF', 'GBM'],
    'R2_Train_Random': [0.99, 0.99, 0.66, 0.96, 0.94, 0.98],
    'R2_Train_Similarity': [0.98, 0.97, 0.64, 0.94, 0.92, 0.96],
    'R2_Test_Random': [0.84, 0.55, 0.44, 0.96, 0.64, 0.66],
    'R2_Test_Similarity': [0.82, 0.53, 0.42, 0.92, 0.62, 0.64],
    'RMSE_Train_Random': [0.009, 0.009, 0.59, 0.19, 0.23, 0.11],
    'RMSE_Train_Similarity': [0.010, 0.010, 0.60, 0.20, 0.24, 0.12],
    'RMSE_Test_Random': [0.34, 0.59, 0.66, 0.19, 0.53, 0.51],
    'RMSE_Test_Similarity': [0.35, 0.60, 0.67, 0.20, 0.54, 0.52],
    'MAE_Train_Random': [0.008, 0.005, 0.39, 0.13, 0.17, 0.09],
    'MAE_Train_Similarity': [0.009, 0.006, 0.40, 0.14, 0.18, 0.10],
    'MAE_Test_Random': [0.19, 0.34, 0.49, 0.13, 0.37, 0.30],
    'MAE_Test_Similarity': [0.20, 0.35, 0.50, 0.14, 0.38, 0.31]
}

# Create DataFrame
df_sabsnmY1 = pd.DataFrame(data)


# Plotting
fig, axs = plt.subplots(3, 2, figsize=(13, 10))

# Define bar width
bar_width = 0.2

# Plot R^2
indices = range(len(df_sabsnmY1['Model']))
axs[0, 0].bar([i - 0.25*bar_width for i in indices], df_sabsnmY1['R2_Train_Random'], width=bar_width, color='gray', edgecolor='black', hatch='//', label='R2 - Train Random')
axs[0, 0].bar([i + 0.25*bar_width for i in indices], df_sabsnmY1['R2_Train_Similarity'], width=bar_width, color='gray', edgecolor='black', hatch='.', label='R2 - Train Similarity')
axs[0, 0].set_ylabel('R²', fontsize=11, fontweight='bold')
axs[0, 0].set_xticks(indices)
axs[0, 0].set_xticklabels(df_sabsnmY1['Model'])
axs[0, 0].legend()

axs[0, 1].bar([i - 0.25*bar_width for i in indices], df_sabsnmY1['R2_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='//', label='R2 - Test Random')
axs[0, 1].bar([i + 0.25*bar_width for i in indices], df_sabsnmY1['R2_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='R2 - Test Similarity')
axs[0, 1].set_ylabel('R²', fontsize=11, fontweight='bold')
axs[0, 1].set_xticks(indices)
axs[0, 1].set_xticklabels(df_sabsnmY1['Model'])
axs[0, 1].legend()

# Plot RMSE
axs[1, 0].bar([i - 0.25*bar_width for i in indices], df_sabsnmY1['RMSE_Train_Random'], width=bar_width, color='gray', edgecolor='black', hatch='*', label='RMSE - Train Random')
axs[1, 0].bar([i + 0.25*bar_width for i in indices], df_sabsnmY1['RMSE_Train_Similarity'], width=bar_width, color='gray', edgecolor='black',hatch='.', label='RMSE - Train Similarity')
axs[1, 0].set_ylabel('RMSE', fontsize=11, fontweight='bold')
axs[1, 0].set_xticks(indices)
axs[1, 0].set_xticklabels(df_sabsnmY1['Model'])
axs[1, 0].set_yscale('log')
axs[1, 0].legend()

axs[1, 1].bar([i - 0.25*bar_width for i in indices], df_sabsnmY1['RMSE_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='*', label='RMSE - Test Random')
axs[1, 1].bar([i + 0.25*bar_width for i in indices], df_sabsnmY1['RMSE_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='RMSE - Test Similarity')
axs[1, 1].set_ylabel('RMSE', fontsize=11, fontweight='bold')
axs[1, 1].set_xticks(indices)
axs[1, 1].set_xticklabels(df_sabsnmY1['Model'])
axs[1, 1].set_yscale('log')
axs[1, 1].legend()

# Plot MAE
axs[2, 0].bar([i - 0.25*bar_width for i in indices], df_sabsnmY1['MAE_Train_Random'], width=bar_width, color='gray',edgecolor='black', hatch='/', label='MAE - Train Random')
axs[2, 0].bar([i + 0.25*bar_width for i in indices], df_sabsnmY1['MAE_Train_Similarity'], width=bar_width, color='gray',edgecolor='black', hatch='.', label='MAE - Train Similarity')
axs[2, 0].set_ylabel('MAE', fontsize=11, fontweight='bold')
axs[2, 0].set_xticks(indices)
axs[2, 0].set_xticklabels(df_sabsnmY1['Model'])
axs[2, 0].set_yscale('log')
axs[2, 0].legend()

axs[2, 1].bar([i - 0.25*bar_width for i in indices], df_sabsnmY1['MAE_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='/', label='MAE - Test Random')
axs[2, 1].bar([i + 0.25*bar_width for i in indices], df_sabsnmY1['MAE_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='MAE - Test Similarity')
axs[2, 1].set_ylabel('MAE', fontsize=11, fontweight='bold')
axs[2, 1].set_xticks(indices)
axs[2, 1].set_xticklabels(df_sabsnmY1['Model'])
axs[2, 1].set_yscale('log')
axs[2, 1].legend()

# General layout
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PL

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data provided for 'PL'
data = {
    'Model': ['SVR', 'NND', 'DL', 'DT', 'RF', 'GBM'],
    'R2_Train_Random': [0.99, 0.99, 0.73, 0.97, 0.94, 0.99],
    'R2_Train_Similarity': [0.98, 0.97, 0.70, 0.95, 0.92, 0.97],
    'R2_Test_Random': [0.66, 0.78, 0.53, 0.97, 0.70, 0.71],
    'R2_Test_Similarity': [0.64, 0.76, 0.50, 0.95, 0.68, 0.69],
    'RMSE_Train_Random': [0.009, 0.005, 0.51, 0.16, 0.23, 0.09],
    'RMSE_Train_Similarity': [0.010, 0.006, 0.52, 0.17, 0.24, 0.10],
    'RMSE_Test_Random': [0.58, 0.46, 0.68, 0.16, 0.54, 0.53],
    'RMSE_Test_Similarity': [0.60, 0.47, 0.70, 0.17, 0.56, 0.55],
    'MAE_Train_Random': [0.009, 0.002, 0.38, 0.11, 0.16, 0.07],
    'MAE_Train_Similarity': [0.010, 0.003, 0.39, 0.12, 0.17, 0.08],
    'MAE_Test_Random': [0.28, 0.29, 0.56, 0.11, 0.39, 0.34],
    'MAE_Test_Similarity': [0.30, 0.31, 0.58, 0.12, 0.40, 0.35]
}

# Create DataFrame
df_pl = pd.DataFrame(data)


# Plotting
fig, axs = plt.subplots(3, 2, figsize=(13, 10))

# Define bar width
bar_width = 0.2

# Plot R^2
indices = range(len(df_pl['Model']))
axs[0, 0].bar([i - 0.25*bar_width for i in indices], df_pl['R2_Train_Random'], width=bar_width, color='gray', edgecolor='black', hatch='//', label='R2 - Train Random')
axs[0, 0].bar([i + 0.25*bar_width for i in indices], df_pl['R2_Train_Similarity'], width=bar_width, color='gray', edgecolor='black', hatch='.', label='R2 - Train Similarity')
axs[0, 0].set_ylabel('R²', fontsize=11, fontweight='bold')
axs[0, 0].set_xticks(indices)
axs[0, 0].set_xticklabels(df_pl['Model'])
axs[0, 0].legend()

axs[0, 1].bar([i - 0.25*bar_width for i in indices], df_pl['R2_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='//', label='R2 - Test Random')
axs[0, 1].bar([i + 0.25*bar_width for i in indices], df_pl['R2_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='R2 - Test Similarity')
axs[0, 1].set_ylabel('R²', fontsize=11, fontweight='bold')
axs[0, 1].set_xticks(indices)
axs[0, 1].set_xticklabels(df_pl['Model'])
axs[0, 1].legend()

# Plot RMSE
axs[1, 0].bar([i - 0.25*bar_width for i in indices], df_pl['RMSE_Train_Random'], width=bar_width, color='gray', edgecolor='black', hatch='*', label='RMSE - Train Random')
axs[1, 0].bar([i + 0.25*bar_width for i in indices], df_pl['RMSE_Train_Similarity'], width=bar_width, color='gray', edgecolor='black',hatch='.', label='RMSE - Train Similarity')
axs[1, 0].set_ylabel('RMSE', fontsize=11, fontweight='bold')
axs[1, 0].set_xticks(indices)
axs[1, 0].set_xticklabels(df_pl['Model'])
axs[1, 0].set_yscale('log')
axs[1, 0].legend()

axs[1, 1].bar([i - 0.25*bar_width for i in indices], df_pl['RMSE_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='*', label='RMSE - Test Random')
axs[1, 1].bar([i + 0.25*bar_width for i in indices], df_pl['RMSE_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='RMSE - Test Similarity')
axs[1, 1].set_ylabel('RMSE', fontsize=11, fontweight='bold')
axs[1, 1].set_xticks(indices)
axs[1, 1].set_xticklabels(df_pl['Model'])
axs[1, 1].set_yscale('log')
axs[1, 1].legend()

# Plot MAE
axs[2, 0].bar([i - 0.25*bar_width for i in indices], df_pl['MAE_Train_Random'], width=bar_width, color='gray',edgecolor='black', hatch='/', label='MAE - Train Random')
axs[2, 0].bar([i + 0.25*bar_width for i in indices], df_pl['MAE_Train_Similarity'], width=bar_width, color='gray',edgecolor='black', hatch='.', label='MAE - Train Similarity')
axs[2, 0].set_ylabel('MAE', fontsize=11, fontweight='bold')
axs[2, 0].set_xticks(indices)
axs[2, 0].set_xticklabels(df_pl['Model'])
axs[2, 0].set_yscale('log')
axs[2, 0].legend()

axs[2, 1].bar([i - 0.25*bar_width for i in indices], df_pl['MAE_Test_Random'], width=bar_width, color='white', edgecolor='black', hatch='/', label='MAE - Test Random')
axs[2, 1].bar([i + 0.25*bar_width for i in indices], df_pl['MAE_Test_Similarity'], width=bar_width, color='white', edgecolor='black', hatch='.', label='MAE - Test Similarity')
axs[2, 1].set_ylabel('MAE', fontsize=11, fontweight='bold')
axs[2, 1].set_xticks(indices)
axs[2, 1].set_xticklabels(df_pl['Model'])
axs[2, 1].set_yscale('log')
axs[2, 1].legend()

# General layout
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
